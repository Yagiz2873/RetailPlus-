# %% [markdown]
# # IMPORTING LIBRARIES AND FILE

# %% [markdown]
# ### Before Starting
# #### Before I Uploaded this dataset to here, I've added new columns (Feature Engineering, from LitDate to Season) and made cross analyses in SQL
# #### and made some minor adjustments in Categories Like : Home Dècor ---> Home Decor in Categories) in Excel

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\Yağız Esmerligil\Desktop\New_Modified_Retail+.xlsx") # file_uploading

# %%
df_copy = df.copy() # copying

# %%
df_copy.head() # head()
# Out:
#        ID  Invoice  StockCode  Quantity  Price  Customer_ID   Country  \
# 0  356509   524003      22445         1   2.95        14649  Portugal
# 1  356510   524003      22079         1   1.65        14649  Portugal
# 2  356511   524003      21866         1   1.25        14649  Portugal
# 3  356512   524003      21592         1   1.25        14649  Portugal
# 4  356513   524003      21592         1   1.25        14649  Portugal
#
#                      Description          Categories               Dates  \
# 0  PENCIL CASE LIFE IS BEAUTIFUL     Office Supplies 2023-09-26 16:04:00
# 1      RIBBON REEL HEARTS DESIGN          Home Decor 2023-09-26 16:04:00
# 2    UNION JACK FLAG LUGGAGE TAG  Travel Accessories 2023-09-26 16:04:00
# 3    RETROSPOT CIGAR BOX MATCHES       Storage Boxes 2023-09-26 16:04:00
# 4    RETROSPOT CIGAR BOX MATCHES       Storage Boxes 2023-09-26 16:04:00
#
#      LitDate      Time  Monetary  Year  LitMonth  Day  Season
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt #Other Useful Libraries

# %% [markdown]
# # EDA PROCESSES

# %%
df_copy.columns # Columns
# Out:
# Index(['ID', 'Invoice', 'StockCode', 'Quantity', 'Price', 'Customer_ID',
#        'Country', 'Description', 'Categories', 'Dates', 'LitDate', 'Time',
#        'Monetary', 'Year', 'LitMonth', 'Day', 'Season'],
#       dtype='object')

# %%
df_copy.index #index
# Out:
# RangeIndex(start=0, stop=702643, step=1)

# %%
df_copy.values[0] # record sample
# Out:
# array([356509, 524003, 22445, 1, 2.95, 14649, 'Portugal',
#        'PENCIL CASE LIFE IS BEAUTIFUL', 'Office Supplies',
#        Timestamp('2023-09-26 16:04:00'), Timestamp('2023-09-26 00:00:00'),
#        datetime.time(16, 4), 2.95, 2023, 9, 26, 'Autumn'], dtype=object)

# %%
df_copy.head() #head()
# Out:
#        ID  Invoice  StockCode  Quantity  Price  Customer_ID   Country  \
# 0  356509   524003      22445         1   2.95        14649  Portugal
# 1  356510   524003      22079         1   1.65        14649  Portugal
# 2  356511   524003      21866         1   1.25        14649  Portugal
# 3  356512   524003      21592         1   1.25        14649  Portugal
# 4  356513   524003      21592         1   1.25        14649  Portugal
#
#                      Description          Categories               Dates  \
# 0  PENCIL CASE LIFE IS BEAUTIFUL     Office Supplies 2023-09-26 16:04:00
# 1      RIBBON REEL HEARTS DESIGN          Home Decor 2023-09-26 16:04:00
# 2    UNION JACK FLAG LUGGAGE TAG  Travel Accessories 2023-09-26 16:04:00
# 3    RETROSPOT CIGAR BOX MATCHES       Storage Boxes 2023-09-26 16:04:00
# 4    RETROSPOT CIGAR BOX MATCHES       Storage Boxes 2023-09-26 16:04:00
#
#      LitDate      Time  Monetary  Year  LitMonth  Day  Season
# ...

# %%
df_copy.tail() #tail()
# Out:
#              ID  Invoice  StockCode  Quantity  Price  Customer_ID Country  \
# 702638  1035782   579446      22576        12   0.85        14121  Israel
# 702639  1035783   579446      22895         6   3.25        14121  Israel
# 702640  1035784   579446      21035         6   3.25        14121  Israel
# 702641  1035785   579446      23247         6   2.89        14121  Israel
# 702642  1035786   579446      23234         6   2.89        14121  Israel
#
#                                 Description     Categories  \
# 702638  SWALLOW WOODEN CHRISTMAS DECORATION  Miscellaneous
# 702639  SET OF 2 TEA TOWELS APPLE AND PEARS  Miscellaneous
# 702640       SET/2 RED RETROSPOT TEA TOWELS  Miscellaneous
# 702641           BISCUIT TIN 50'S CHRISTMAS  Miscellaneous
# 702642        BISCUIT TIN VINTAGE CHRISTMAS  Miscellaneous
#
#                      Dates    LitDate      Time  Monetary  Year  LitMonth  \
# 702638 2023-11-29 13:43:00 2023-11-29  13:43:00     10.20  2023        11
# ...

# %%
df_copy.shape #shape
# Out:
# (702643, 17)

# %%
df_copy.info() #info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702643 entries, 0 to 702642
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           702643 non-null  int64
#  1   Invoice      702643 non-null  int64
#  2   StockCode    702643 non-null  int64
#  3   Quantity     702643 non-null  int64
#  4   Price        702643 non-null  float64
#  5   Customer_ID  702643 non-null  int64
#  6   Country      702643 non-null  object
#  7   Description  680951 non-null  object
#  8   Categories   680951 non-null  object
#  9   Dates        702643 non-null  datetime64[ns]
#  10  LitDate      702643 non-null  datetime64[ns]
#  11  Time         702643 non-null  object
#  12  Monetary     702643 non-null  float64
#  13  Year         702643 non-null  int64
#  14  LitMonth     702643 non-null  int64
#  15  Day          702643 non-null  int64
#  16  Season       702643 non-null  object
# ...

# %%
df_copy.describe() #describe()
# Out:
#                  ID        Invoice      StockCode       Quantity  \
# count  7.026430e+05  702643.000000  702643.000000  702643.000000
# mean   5.349056e+05  537752.070438   28244.417380      13.005045
# min    1.000000e+00  489434.000000   10002.000000       1.000000
# 25%    2.758735e+05  516187.000000   21731.000000       2.000000
# 50%    5.259460e+05  537224.000000   22383.000000       6.000000
# 75%    8.061915e+05  561488.000000   22931.000000      12.000000
# max    1.048564e+06  580501.000000   90208.000000    9456.000000
# std    3.020649e+05   26136.393445   17769.982172      61.459454
#
#                Price    Customer_ID                          Dates  \
# count  702643.000000  702643.000000                         702643
# mean        2.937546   15327.211314  2023-07-18 20:36:50.518087168
# min         0.000000   12346.000000            2022-12-01 07:45:00
# 25%         1.250000   13975.000000            2023-04-19 13:29:00
# ...

# %%
df_copy.dtypes #dtypes
# Out:
# ID                      int64
# Invoice                 int64
# StockCode               int64
# Quantity                int64
# Price                 float64
# Customer_ID             int64
# Country                object
# Description            object
# Categories             object
# Dates          datetime64[ns]
# LitDate        datetime64[ns]
# Time                   object
# Monetary              float64
# Year                    int64
# LitMonth                int64
# Day                     int64
# Season                 object
# dtype: object

# %%
df_copy.isnull().sum()/df_copy.shape[0] # checking null values / missng values
# Out:
# ID             0.000000
# Invoice        0.000000
# StockCode      0.000000
# Quantity       0.000000
# Price          0.000000
# Customer_ID    0.000000
# Country        0.000000
# Description    0.030872
# Categories     0.030872
# Dates          0.000000
# LitDate        0.000000
# Time           0.000000
# Monetary       0.000000
# Year           0.000000
# LitMonth       0.000000
# Day            0.000000
# Season         0.000000
# dtype: float64

# %% [markdown]
# ### CHANGING SOME COLUMNS' TYPES AND CATEGORIZING COLUMNS

# %%
df_copy["Customer_ID"] = df_copy["Customer_ID"].astype('category')

# %%
df_copy["StockCode"] = df_copy["StockCode"].astype('category')

# %%
df_copy["Invoice"] = df_copy["Invoice"].astype('category')

# %%
df_copy["Dates"] = df_copy["Dates"].astype('object')
df_copy["LitDate"] = df_copy["LitDate"].astype('object')

# %%
num_columns = ["ID","Quantity","Price","Monetary","Year","LitMonth","Day"]
cat_columns = ["Country","Invoice","Description","Categories","Season","Customer_ID","StockCode"] #categorizing columns
date_columns = ["Dates","LitDate","Time"]

# %%
for col in cat_columns:
    print(df_copy[col].value_counts())
    print("-----------------------------")
# Out:
# Country
# United Kingdom          195029
# EIRE                     23886
# Greece                   23655
# Germany                  22357
# France                   21235
# Switzerland              17198
# Spain                    15085
# Belgium                  14864
# Austria                  14597
# Thailand                 14529
# Finland                  14135
# Sweden                   13995
# Cyprus                   13735
# Netherlands              13498
# Nigeria                  13434
# Singapore                13423
# Poland                   13050
# Italy                    12752
# Australia                12053
# Lebanon                  11763
# Japan                    11651
# Portugal                 11456
# Norway                   11393
# Lithuania                11375
# Denmark                  11329
# Brazil                   10808
# USA                      10678
# European Community       10502
# RSA                      10162
# Channel Islands           9921
# ...

# %%
for col in cat_columns:
    print(df_copy[col].value_counts()/df.shape[0])
    print("-----------------------------") #value_counts() for categorical columns
# Out:
# Country
# United Kingdom          0.277565
# EIRE                    0.033995
# Greece                  0.033666
# Germany                 0.031818
# France                  0.030222
# Switzerland             0.024476
# Spain                   0.021469
# Belgium                 0.021154
# Austria                 0.020774
# Thailand                0.020678
# Finland                 0.020117
# Sweden                  0.019918
# Cyprus                  0.019548
# Netherlands             0.019210
# Nigeria                 0.019119
# Singapore               0.019104
# Poland                  0.018573
# Italy                   0.018149
# Australia               0.017154
# Lebanon                 0.016741
# Japan                   0.016582
# Portugal                0.016304
# Norway                  0.016214
# Lithuania               0.016189
# Denmark                 0.016123
# Brazil                  0.015382
# USA                     0.015197
# European Community      0.014946
# ...

# %%
#Histograms
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth":1.5})
sns.set_palette("husl" ,1)
for col in num_columns:
    sns.histplot(data=df_copy[col], bins=25, color="#86bf91")
    plt.show()

# %%
cat_columns
# Out:
# ['Country',
#  'Invoice',
#  'Description',
#  'Categories',
#  'Season',
#  'Customer_ID',
#  'StockCode']

# %%
num_columns
# Out:
# ['ID', 'Quantity', 'Price', 'Monetary', 'Year', 'LitMonth', 'Day']

# %%
#Box-plots
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth":1.5})
sns.set_palette("husl" ,1)
for col in num_columns:
    sns.boxplot(y=df_copy[col], color="#86bf91", width=.1)
    plt.show()

# %%
plt.figure(figsize=(16, 6))
heatmap=sns.heatmap(data=df_copy[["Quantity","Price","Monetary"]].corr(),annot=True,cmap="Greens")
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
plt.figure(figsize=(16, 6))
heatmap=sns.heatmap(data=df_copy[num_columns].corr(),annot=True,cmap="Greens") 
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(df_copy[num_columns].corr(), dtype=bool))
heatmap=sns.heatmap(data=df_copy[num_columns].corr(),annot=True,cmap="Greens",mask=mask) 
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Missing Values and Other Values Handling

# %% [markdown]
# #### In this dataset, I've preferred removing NA and Unspecified Values to make the dataset clearer for ML algorithms. Fiiling with any other values can be deceptive
# #### Because this values are in categorical columns not numerical columns.
# #### Total records that have NA and Unspecifies are approxiamtely 30000 of 700000. So it's 3%. I can remove these

# %% [markdown]
# ### Unspecified

# %%
df_copy[df_copy["Country"]=="Unspecified"]
# Out:
#              ID Invoice StockCode  Quantity  Price Customer_ID      Country  \
# 353      356899  524025     21232        72   1.06       13798  Unspecified
# 354      356901  524025     21231        72   1.06       13798  Unspecified
# 355      356903  524025     20685        10   6.75       13798  Unspecified
# 356      356904  524025     20718       100   1.06       13798  Unspecified
# 357      356905  524025     85150        48   2.10       13798  Unspecified
# ...         ...     ...       ...       ...    ...         ...          ...
# 700026  1032084  579148     22274         3   2.95       17523  Unspecified
# 700027  1032085  579148     22130        24   0.85       17523  Unspecified
# 700028  1032086  579148     22273         3   2.95       17523  Unspecified
# 700029  1032087  579148     22940         6   4.25       17523  Unspecified
# 700030  1032088  579148     22509         1  16.95       17523  Unspecified
#
# ...

# %%
print("# of Unspecified Columns in Country:",df_copy[df_copy["Country"]=="Unspecified"]["Country"].count())
# Out:
# # of Unspecified Columns in Country: 9363

# %%
df_copy_cleaned = df_copy.loc[df_copy["Country"] != 'Unspecified']
print(df_copy_cleaned)
# Out:
#              ID Invoice StockCode  Quantity  Price Customer_ID   Country  \
# 0        356509  524003     22445         1   2.95       14649  Portugal
# 1        356510  524003     22079         1   1.65       14649  Portugal
# 2        356511  524003     21866         1   1.25       14649  Portugal
# 3        356512  524003     21592         1   1.25       14649  Portugal
# 4        356513  524003     21592         1   1.25       14649  Portugal
# ...         ...     ...       ...       ...    ...         ...       ...
# 702638  1035782  579446     22576        12   0.85       14121    Israel
# 702639  1035783  579446     22895         6   3.25       14121    Israel
# 702640  1035784  579446     21035         6   3.25       14121    Israel
# 702641  1035785  579446     23247         6   2.89       14121    Israel
# 702642  1035786  579446     23234         6   2.89       14121    Israel
#
#                                 Description          Categories  \
# ...

# %%
print("# of Unspecified Columns in Country:",df_copy_cleaned[df_copy_cleaned["Country"]=="Unspecified"]["Country"].count())
# Out:
# # of Unspecified Columns in Country: 0

# %% [markdown]
# ### NA Values

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None) #to display all

# %%
print(df_copy_cleaned.info()) # to check whether Unspecified values were removed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 693280 entries, 0 to 702642
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           693280 non-null  int64
#  1   Invoice      693280 non-null  category
#  2   StockCode    693280 non-null  category
#  3   Quantity     693280 non-null  int64
#  4   Price        693280 non-null  float64
#  5   Customer_ID  693280 non-null  category
#  6   Country      693280 non-null  object
#  7   Description  671853 non-null  object
#  8   Categories   671853 non-null  object
#  9   Dates        693280 non-null  object
#  10  LitDate      693280 non-null  object
#  11  Time         693280 non-null  object
#  12  Monetary     693280 non-null  float64
#  13  Year         693280 non-null  int64
#  14  LitMonth     693280 non-null  int64
#  15  Day          693280 non-null  int64
#  16  Season       693280 non-null  object
# ...

# %%
df_copy_cleaned.isnull().sum()
# Out:
# ID                 0
# Invoice            0
# StockCode          0
# Quantity           0
# Price              0
# Customer_ID        0
# Country            0
# Description    21427
# Categories     21427
# Dates              0
# LitDate            0
# Time               0
# Monetary           0
# Year               0
# LitMonth           0
# Day                0
# Season             0
# dtype: int64

# %%
df_copy_cleaned["Description"] = df_copy_cleaned["Description"].astype('object')
df_copy_cleaned["Categories"] = df_copy_cleaned["Categories"].astype('object') # change type to object
# Out:
# C:\Users\Yağız Esmerligil\AppData\Local\Temp\ipykernel_23092\1288035848.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_cleaned["Description"] = df_copy_cleaned["Description"].astype('object')
# C:\Users\Yağız Esmerligil\AppData\Local\Temp\ipykernel_23092\1288035848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy_cleaned["Categories"] = df_copy_cleaned["Categories"].astype('object') # change type to object

# %%
df_copy_cleaned.dtypes
# Out:
# ID                int64
# Invoice        category
# StockCode      category
# Quantity          int64
# Price           float64
# Customer_ID    category
# Country          object
# Description      object
# Categories       object
# Dates            object
# LitDate          object
# Time             object
# Monetary        float64
# Year              int64
# LitMonth          int64
# Day               int64
# Season           object
# dtype: object

# %%
df_copy_cleaned_final = df_copy_cleaned.dropna(subset = ["Description"]) # with .dropna(), we can remove na values

# %%
df_copy_cleaned_final.isnull().sum()
# Out:
# ID             0
# Invoice        0
# StockCode      0
# Quantity       0
# Price          0
# Customer_ID    0
# Country        0
# Description    0
# Categories     0
# Dates          0
# LitDate        0
# Time           0
# Monetary       0
# Year           0
# LitMonth       0
# Day            0
# Season         0
# dtype: int64

# %%
df_copy_cleaned_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 671853 entries, 0 to 702642
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           671853 non-null  int64
#  1   Invoice      671853 non-null  category
#  2   StockCode    671853 non-null  category
#  3   Quantity     671853 non-null  int64
#  4   Price        671853 non-null  float64
#  5   Customer_ID  671853 non-null  category
#  6   Country      671853 non-null  object
#  7   Description  671853 non-null  object
#  8   Categories   671853 non-null  object
#  9   Dates        671853 non-null  object
#  10  LitDate      671853 non-null  object
#  11  Time         671853 non-null  object
#  12  Monetary     671853 non-null  float64
#  13  Year         671853 non-null  int64
#  14  LitMonth     671853 non-null  int64
#  15  Day          671853 non-null  int64
#  16  Season       671853 non-null  object
# ...

# %% [markdown]
# # Outlier Handling
# #### In this dataset, I've preferred outlier capping techniques rather than removing them directly.
# #### Because there are too many outliers to remove. If I remove them directly, approximately %20 of total records will be lost. This is too much
# #### For %75 upper_limit and %25 lower_limit from IQR calculations
# #### Quantity:  from 27  to -13
# #### Price: from 7,5 to -2,5
# #### Monetary: from 41,325 to -16,875
# #### Any values that aren't in these ranges will be outliers. So there are approxiamately 150000 records that have outliers
# #### No negative outliers only positive ones exist

# %%
#Box-plots
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth":1.5})
sns.set_palette("husl" ,1)
for col in num_columns:
    sns.boxplot(y=df_copy_cleaned_final[col], color="#86bf91", width=.1)
    plt.show()

# %%
# # of Records that have Outliers
df_copy_cleaned_final[df_copy_cleaned_final["Quantity"]>27]["Quantity"].count()
# Out:
# 42664

# %%
df_copy_cleaned_final[df_copy_cleaned_final["Price"]>7.5]["Price"].count()
# Out:
# 55634

# %%
df_copy_cleaned_final[df_copy_cleaned_final["Monetary"]>41.325]["Monetary"].count()
# Out:
# 52767

# %%
df_copy_cleaned_final_trial = df_copy_cleaned_final.copy()

# %%
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth":1.5})
sns.set_palette("husl" ,1)
for col in num_columns:
    sns.boxplot(y=df_copy_cleaned_final_trial[col], color="#86bf91", width=.1)
    plt.show()

# %% [markdown]
# ### Outlier Capping By Using Quantiles

# %% [markdown]
# #### I've chosen this technique that uses IQR and quantiles for capping. Because Quantity, Price and Monetary have skewed distributions.
# #### If you have datas that have normal distributions you can use mean and std for capping instead.

# %%
# UL = 0.75 and LL= 0.25 gave me the best results.
def handleOutliersByCapping(dataframe,var):
    q3 = dataframe[var].quantile(0.75)  
    q1 = dataframe[var].quantile(0.25)
    print("Q3: ",q3)
    print("Q1",q1)
    IQR = q3 - q1
    print("IQR: ",IQR)
    lower_limit = q1 - (IQR * 1.5)
    print("Lower Limit: ",lower_limit)
    upper_limit = q3 + (IQR * 1.5)
    print("Upper Limit: ",upper_limit)
    dataframe[var] = np.where(dataframe[var]> upper_limit, upper_limit,
                        np.where(dataframe[var]< lower_limit, lower_limit,
                          dataframe[var]))

# %%
outlier_cols = ["Quantity","Price","Monetary"]

# %%
for col in outlier_cols:
    handleOutliersByCapping(df_copy_cleaned_final_trial,col)
# Out:
# Q3:  12.0
# Q1 2.0
# IQR:  10.0
# Lower Limit:  -13.0
# Upper Limit:  27.0
# Q3:  3.75
# Q1 1.25
# IQR:  2.5
# Lower Limit:  -2.5
# Upper Limit:  7.5
# Q3:  19.5
# Q1 4.95
# IQR:  14.55
# Lower Limit:  -16.875000000000004
# Upper Limit:  41.325

# %%
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth":1.5})
sns.set_palette("husl" ,1)
for col in num_columns:
    sns.boxplot(y=df_copy_cleaned_final_trial[col], color="#86bf91", width=.1)
    plt.show()

# %%
df_copy_cleaned_final_trial.to_excel("cleanedData.xlsx")
